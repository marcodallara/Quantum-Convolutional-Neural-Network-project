# %%
import tensorflow as tf
import tensorflow_quantum as tfq

import cirq
import sympy
import numpy as np
from numpy import linalg as LA
import copy
import itertools

# visualization tools
# %matplotlib inline
import matplotlib.pyplot as plt
from cirq.contrib.svg import SVGCircuit
# Out:
# 2023-07-05 09:38:03.755812: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64::/usr/local/cuda-10.2/lib64/
# 2023-07-05 09:38:03.755833: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-07-05 09:38:09.313862: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-07-05 09:38:09.313962: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (claudio-CG8270): /proc/driver/nvidia/version does not exist
# 2023-07-05 09:38:09.316118: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Functions for amplitude encoding

# %%
def gen_angles(x):
    """function that generates angles for amplitude encoding"""
    
    if len(x)>1:
        new_x = np.zeros(int(len(x)/2))
        
        for k in range(len(new_x)):
            new_x[k] = np.sqrt(x[2*k]**2 + x[2*k+1]**2)
        
        inner_angles = gen_angles(new_x)
                
        angles = np.zeros(int(len(x)/2))

        for k in range(len(new_x)):
            if(new_x[k]!=0):
                if(x[2*k]>0):
                    angles[k] = 2*np.arcsin(x[2*k+1]/new_x[k])
                else:
                    angles[k] = 2*np.pi - 2*np.arcsin(x[2*k+1]/new_x[k])
            else:
                angles[k] = 0
        
        angles = np.concatenate((inner_angles, angles))
        
        return np.array(angles)
    
    else: return np.ones(0)
    
    
    
n_0 = 20  # Number of elements in the array
array = [0] * n_0  # Initialize the array with zeros

# Calculate the cumulative sums of powers of 2
for i in range(n_0):
    if i == 0:
        array[i] = 1
    else:
        array[i] = array[i-1] + 2 ** i
array = np.array(array)-1



def level(k):
    
    for i in range(len(array)):
        
        if(k==0): return 0
        
        if (k>array[i] and k<=array[i+1]): return i+1
    


def parity(level):
    
    n = level
    combinations = list(itertools.product([0, 1], repeat=n))
    return (combinations)
    
def gen_circuit(qubits, angles): #recive a list of n qubits
    
    circuit = cirq.Circuit()
    counter = 0
    levels = [level(np.arange(0,len(angles)+1)[i]) for i in range(len(angles)+1)]


    for k in range(len(angles)):
        
        j = levels[k]
        
        if(j!=levels[k-1] and k>0):
            counter = 0
        
        p = parity(j)
        op = cirq.ry(angles[k]).on(qubits[j]).controlled_by(*qubits[0:j], control_values=parity(j)[counter])
        #for i in range(j):
         #   op = op.controlled_by(qubits[j-1-i], control_values=[1])
        
        counter += 1
        circuit += op

    return circuit

# %%
def amplitude_encoding(qubits, data, print_it=False):
    
    """ Make amplitude encoding. Return the circuit """
    
    N = len(data) #dimension of the vector
    n = np.log2(N) #number of qubits
    
    angles = np.hstack(gen_angles(data)) #compute the angles to do amp encoding

    circuit = gen_circuit(qubits, angles) #make the circuit
    
    if (print_it==True):
        SVGCircuit(circuit)
        
    return circuit

# %% [markdown]
# ## Functions of general circuits

# %%
def one_qubit_unitary(bit, symbols):
    """Make a Cirq circuit enacting a rotation of the bloch sphere about the X,
    Y and Z axis, that depends on the values in `symbols`.
    """
    return cirq.Circuit(
        cirq.X(bit)**symbols[0],
        cirq.Y(bit)**symbols[1],
        cirq.Z(bit)**symbols[2])


def two_qubit_unitary(bits, symbols):
    """Make a Cirq circuit that creates an arbitrary two qubit unitary."""
    circuit = cirq.Circuit()
    circuit += one_qubit_unitary(bits[0], symbols[0:3])
    circuit += one_qubit_unitary(bits[1], symbols[3:6])
    circuit += [cirq.ZZ(*bits)**symbols[6]]
    circuit += [cirq.YY(*bits)**symbols[7]]
    circuit += [cirq.XX(*bits)**symbols[8]]
    circuit += one_qubit_unitary(bits[0], symbols[9:12])
    circuit += one_qubit_unitary(bits[1], symbols[12:])
    return circuit


def two_qubit_pool(source_qubit, sink_qubit, symbols):
    """Make a Cirq circuit to do a parameterized 'pooling' operation, which
    attempts to reduce entanglement down from two qubits to just one."""
    pool_circuit = cirq.Circuit()
    sink_basis_selector = one_qubit_unitary(sink_qubit, symbols[0:3])
    source_basis_selector = one_qubit_unitary(source_qubit, symbols[3:6])
    pool_circuit.append(sink_basis_selector)
    pool_circuit.append(source_basis_selector)
    pool_circuit.append(cirq.CNOT(control=source_qubit, target=sink_qubit))
    pool_circuit.append(sink_basis_selector**-1)
    return pool_circuit

def qfcc_3q(bits, symbols):
    """Make a 3 qubit quantum FCC"""
    
    circuit = cirq.Circuit()

    circuit += cirq.Y(bits[0])**(symbols[0])
    circuit += cirq.Y(bits[1])**(symbols[1])
    circuit += cirq.Y(bits[2])**(symbols[2])

    circuit += cirq.Z(bits[0])**(symbols[3])
    circuit += cirq.Z(bits[1])**(symbols[4])
    circuit += cirq.Z(bits[2])**(symbols[5])

    circuit += cirq.CNOT(bits[0], bits[1])
    circuit += cirq.CNOT(bits[0], bits[2])
    circuit += cirq.CNOT(bits[1], bits[2])

    circuit += cirq.Y(bits[0])**(symbols[6])
    circuit += cirq.Y(bits[1])**(symbols[7])
    circuit += cirq.Y(bits[2])**(symbols[8])

    circuit += cirq.Z(bits[0])**(symbols[9])
    circuit += cirq.Z(bits[1])**(symbols[10])
    circuit += cirq.Z(bits[2])**(symbols[11])

    circuit += cirq.CNOT(bits[0], bits[1])
    circuit += cirq.CNOT(bits[0], bits[2])
    circuit += cirq.CNOT(bits[1], bits[2])

    circuit += cirq.Y(bits[0])**(symbols[12])
    circuit += cirq.Y(bits[1])**(symbols[13])
    circuit += cirq.Y(bits[2])**(symbols[14])
    
    return circuit

# %%
def quantum_conv_circuit(bits, symbols):
    """Quantum Convolution Layer following the above diagram.
    Return a Cirq circuit with the cascade of `two_qubit_unitary` applied
    to all pairs of qubits in `bits` as in the diagram above.
    """
    circuit = cirq.Circuit()
    for first, second in zip(bits[0::2], bits[1::2]):
        circuit += two_qubit_unitary([first, second], symbols)
    for first, second in zip(bits[1::2], bits[2::2] + [bits[0]]):
        circuit += two_qubit_unitary([first, second], symbols)
        
    return circuit


def quantum_pool_circuit(source_bits, sink_bits, symbols):
    """A layer that specifies a quantum pooling operation.
    A Quantum pool tries to learn to pool the relevant information from two
    qubits onto 1.
    """
    circuit = cirq.Circuit()
    for source, sink in zip(source_bits, sink_bits):
        circuit += two_qubit_pool(source, sink, symbols)
    return circuit

# %% [markdown]
# ## Visualization of pooling and convulational layers

# %%
#plot che pooling circuit

test_bits = cirq.GridQubit.rect(1, 6)

SVGCircuit(
    quantum_pool_circuit(test_bits[:3], test_bits[3:], sympy.symbols('x0:6')))
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.

# %%
#plot the convulational circuit

SVGCircuit(
    quantum_conv_circuit(cirq.GridQubit.rect(1, 6), sympy.symbols('x0:15')))
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.

# %% [markdown]
# ## Create the model
# Decide how many convulational layers, pooling etc....

# %%
def create_model_circuit(qubits):
    """Create sequence of alternating convolution and pooling operators 
    which gradually shrink over time."""
    model_circuit = cirq.Circuit()
    symbols = sympy.symbols('qconv0:51')
    # Cirq uses sympy.Symbols to map learnable variables. TensorFlow Quantum
    # scans incoming circuits and replaces these with TensorFlow variables.
    model_circuit += quantum_conv_circuit(qubits, symbols[0:15])
    #model_circuit += two_qubit_unitary(qubits[4:6], symbols[0:15])
    model_circuit += quantum_pool_circuit(qubits[:3], qubits[3:],
                                          symbols[15:21])
    #model_circuit += two_qubit_unitary(qubits[4:6], symbols[21:36])
    model_circuit += quantum_conv_circuit(qubits[3:], symbols[21:36])

    model_circuit += qfcc_3q(qubits[3:], symbols[36:51])
    
    #model_circuit += (cirq.r(symbols[36]) * cirq.Y(symbols[36])).controlled_by(qubits[5])
    
    #cirq.ControlledGate(cirq.rx(symbols[36]) * cirq.ry(symbols[37]) * cirq.rz(symbols[38])).on(qubits[4], qubits[5])
    #model_circuit += cirq.ControlledGate(my_U).on(qubits[4], qubits[5])
    #model_circuit += cirq.Circuit(custom_gate.on(*qubits[2:4]))
    #model_circuit += quantum_fc_circuit(qubits[3:], symbols[36:75])

    
    return model_circuit


from tensorflow_quantum import differentiators


qubits = cirq.GridQubit.rect(1, 6) #grid of qubit 
readout_operators = cirq.Z(qubits[-1]) #grid of operator i want to average on (final expected value)

# Build a sequential model enacting the logic in 1.3 of this notebook.
inputs = tf.keras.Input(shape=(), dtype=tf.dtypes.string) #still general input

#define the differentiator
#differentiator = differentiators.ParameterShift()


#define the model 
quantum_model = tfq.layers.PQC(create_model_circuit(qubits),readout_operators)(inputs)

qcnn_model = tf.keras.Model(inputs=[inputs], outputs=[quantum_model])

# Show the keras plot of the model
tf.keras.utils.plot_model(qcnn_model,
                          show_shapes=True,
                          show_layer_names=False,
                          dpi=70)
# Out:
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %% [markdown]
# ## Load data of amplitude encoding

# %%
import json

# Open the file in read mode
with open('amplitude_encoding_train_4pixelSquareChuncks.json', 'r') as f:
    # Use json.load() to read the contents of the file
    new_circuit = json.load(f)

# Close the file
f.close()
train_circuits_data = [cirq.read_json(json_text=new_circuit[i]) for i in range((5000))]

# Open the file in read mode
with open('amplitude_encoding_test_4pixelSquareChuncks.json', 'r') as f:
    # Use json.load() to read the contents of the file
    new_circuit = json.load(f)

# Close the file
f.close()
test_circuits_data = [cirq.read_json(json_text=new_circuit[i]) for i in range((500))]

y_train = np.loadtxt("y_train.txt")
y_test = np.loadtxt("y_test.txt")

y_train = y_train[:5000]
y_test = y_test[:500]

# %%
# convert to tensors
train_circuits_data = tfq.convert_to_tensor(train_circuits_data)
test_circuits_data = tfq.convert_to_tensor(test_circuits_data)

# %%
# Custom accuracy metric.
@tf.function
def custom_accuracy(y_true, y_pred):
    y_true = tf.squeeze(y_true)
    y_pred = tf.map_fn(lambda x: 1.0 if x >= 0 else -1.0, y_pred)
    return tf.keras.backend.mean(tf.keras.backend.equal(y_true, y_pred))


qcnn_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                   loss=tf.losses.mse,
                   metrics=[custom_accuracy])

# %%
history = qcnn_model.fit(x=train_circuits_data,
                         y=y_train,
                         batch_size=64,
                         epochs=50,
                         verbose=1,
                         validation_data=(test_circuits_data, y_test))
# Out:
# Epoch 1/50
# 79/79 [==============================] - 40s 494ms/step - loss: 0.6915 - custom_accuracy: 0.9078 - val_loss: 0.6713 - val_custom_accuracy: 0.9313
# Epoch 2/50
# 79/79 [==============================] - 41s 517ms/step - loss: 0.6106 - custom_accuracy: 0.9385 - val_loss: 0.6372 - val_custom_accuracy: 0.9435
# Epoch 3/50
# 79/79 [==============================] - 40s 510ms/step - loss: 0.5739 - custom_accuracy: 0.9446 - val_loss: 0.6134 - val_custom_accuracy: 0.9352
# Epoch 4/50
# 79/79 [==============================] - 38s 484ms/step - loss: 0.5496 - custom_accuracy: 0.9462 - val_loss: 0.5981 - val_custom_accuracy: 0.9416
# Epoch 5/50
# 79/79 [==============================] - 38s 478ms/step - loss: 0.5338 - custom_accuracy: 0.9474 - val_loss: 0.5849 - val_custom_accuracy: 0.9401
# Epoch 6/50
# 79/79 [==============================] - 37s 475ms/step - loss: 0.5238 - custom_accuracy: 0.9462 - val_loss: 0.5734 - val_custom_accuracy: 0.9361
# Epoch 7/50
# 79/79 [==============================] - 37s 472ms/step - loss: 0.5160 - custom_accuracy: 0.9450 - val_loss: 0.5661 - val_custom_accuracy: 0.9274
# Epoch 8/50
# 79/79 [==============================] - 40s 505ms/step - loss: 0.5102 - custom_accuracy: 0.9440 - val_loss: 0.5559 - val_custom_accuracy: 0.9322
# Epoch 9/50
# 79/79 [==============================] - 37s 473ms/step - loss: 0.5038 - custom_accuracy: 0.9466 - val_loss: 0.5419 - val_custom_accuracy: 0.9264
# Epoch 10/50
# 79/79 [==============================] - 38s 488ms/step - loss: 0.4938 - custom_accuracy: 0.9482 - val_loss: 0.5206 - val_custom_accuracy: 0.9283
# Epoch 11/50
# 79/79 [==============================] - 37s 467ms/step - loss: 0.4765 - custom_accuracy: 0.9456 - val_loss: 0.4983 - val_custom_accuracy: 0.9444
# Epoch 12/50
# 79/79 [==============================] - 40s 504ms/step - loss: 0.4607 - custom_accuracy: 0.9440 - val_loss: 0.4896 - val_custom_accuracy: 0.9420
# Epoch 13/50
# 79/79 [==============================] - 41s 520ms/step - loss: 0.4501 - custom_accuracy: 0.9464 - val_loss: 0.4816 - val_custom_accuracy: 0.9361
# Epoch 14/50
# 79/79 [==============================] - 39s 498ms/step - loss: 0.4401 - custom_accuracy: 0.9464 - val_loss: 0.4795 - val_custom_accuracy: 0.9342
# Epoch 15/50
# 79/79 [==============================] - 40s 503ms/step - loss: 0.4320 - custom_accuracy: 0.9460 - val_loss: 0.4755 - val_custom_accuracy: 0.9303
# Epoch 16/50
# 79/79 [==============================] - 41s 522ms/step - loss: 0.4261 - custom_accuracy: 0.9466 - val_loss: 0.4714 - val_custom_accuracy: 0.9279
# Epoch 17/50
# 79/79 [==============================] - 41s 517ms/step - loss: 0.4221 - custom_accuracy: 0.9484 - val_loss: 0.4681 - val_custom_accuracy: 0.9279
# Epoch 18/50
# 79/79 [==============================] - 40s 501ms/step - loss: 0.4191 - custom_accuracy: 0.9474 - val_loss: 0.4660 - val_custom_accuracy: 0.9298
# Epoch 19/50
# 79/79 [==============================] - 40s 508ms/step - loss: 0.4171 - custom_accuracy: 0.9478 - val_loss: 0.4639 - val_custom_accuracy: 0.9337
# Epoch 20/50
# 79/79 [==============================] - 41s 519ms/step - loss: 0.4155 - custom_accuracy: 0.9482 - val_loss: 0.4658 - val_custom_accuracy: 0.9307
# Epoch 21/50
# 79/79 [==============================] - 41s 521ms/step - loss: 0.4148 - custom_accuracy: 0.9484 - val_loss: 0.4605 - val_custom_accuracy: 0.9361
# Epoch 22/50
# 79/79 [==============================] - 38s 477ms/step - loss: 0.4130 - custom_accuracy: 0.9492 - val_loss: 0.4597 - val_custom_accuracy: 0.9357
# Epoch 23/50
# 79/79 [==============================] - 39s 498ms/step - loss: 0.4117 - custom_accuracy: 0.9458 - val_loss: 0.4593 - val_custom_accuracy: 0.9361
# Epoch 24/50
# 79/79 [==============================] - 41s 521ms/step - loss: 0.4112 - custom_accuracy: 0.9502 - val_loss: 0.4585 - val_custom_accuracy: 0.9420
# Epoch 25/50
# 79/79 [==============================] - 41s 517ms/step - loss: 0.4110 - custom_accuracy: 0.9506 - val_loss: 0.4565 - val_custom_accuracy: 0.9386
# Epoch 26/50
# 79/79 [==============================] - 39s 492ms/step - loss: 0.4092 - custom_accuracy: 0.9498 - val_loss: 0.4556 - val_custom_accuracy: 0.9420
# Epoch 27/50
# 79/79 [==============================] - 38s 486ms/step - loss: 0.4085 - custom_accuracy: 0.9513 - val_loss: 0.4553 - val_custom_accuracy: 0.9366
# Epoch 28/50
# 79/79 [==============================] - 39s 491ms/step - loss: 0.4075 - custom_accuracy: 0.9513 - val_loss: 0.4549 - val_custom_accuracy: 0.9346
# Epoch 29/50
# 79/79 [==============================] - 41s 515ms/step - loss: 0.4066 - custom_accuracy: 0.9519 - val_loss: 0.4544 - val_custom_accuracy: 0.9346
# Epoch 30/50
# 79/79 [==============================] - 41s 517ms/step - loss: 0.4058 - custom_accuracy: 0.9513 - val_loss: 0.4538 - val_custom_accuracy: 0.9346
# Epoch 31/50
# 79/79 [==============================] - 39s 492ms/step - loss: 0.4049 - custom_accuracy: 0.9517 - val_loss: 0.4520 - val_custom_accuracy: 0.9346
# Epoch 32/50
# 79/79 [==============================] - 39s 491ms/step - loss: 0.4037 - custom_accuracy: 0.9515 - val_loss: 0.4520 - val_custom_accuracy: 0.9366
# Epoch 33/50
# 79/79 [==============================] - 38s 487ms/step - loss: 0.4028 - custom_accuracy: 0.9527 - val_loss: 0.4508 - val_custom_accuracy: 0.9322
# Epoch 34/50
# 79/79 [==============================] - 38s 478ms/step - loss: 0.4021 - custom_accuracy: 0.9508 - val_loss: 0.4492 - val_custom_accuracy: 0.9342
# Epoch 35/50
# 79/79 [==============================] - 39s 499ms/step - loss: 0.4008 - custom_accuracy: 0.9508 - val_loss: 0.4502 - val_custom_accuracy: 0.9342
# Epoch 36/50
# 79/79 [==============================] - 39s 492ms/step - loss: 0.4000 - custom_accuracy: 0.9509 - val_loss: 0.4488 - val_custom_accuracy: 0.9386
# Epoch 37/50
# 79/79 [==============================] - 39s 500ms/step - loss: 0.3992 - custom_accuracy: 0.9484 - val_loss: 0.4486 - val_custom_accuracy: 0.9401
# Epoch 38/50
# 79/79 [==============================] - 40s 504ms/step - loss: 0.3989 - custom_accuracy: 0.9529 - val_loss: 0.4481 - val_custom_accuracy: 0.9381
# Epoch 39/50
# 79/79 [==============================] - 39s 499ms/step - loss: 0.3982 - custom_accuracy: 0.9508 - val_loss: 0.4482 - val_custom_accuracy: 0.9381
# Epoch 40/50
# 79/79 [==============================] - 41s 516ms/step - loss: 0.3978 - custom_accuracy: 0.9519 - val_loss: 0.4479 - val_custom_accuracy: 0.9381
# Epoch 41/50
# 79/79 [==============================] - 40s 512ms/step - loss: 0.3977 - custom_accuracy: 0.9513 - val_loss: 0.4480 - val_custom_accuracy: 0.9420
# Epoch 42/50
# 79/79 [==============================] - 42s 532ms/step - loss: 0.3979 - custom_accuracy: 0.9515 - val_loss: 0.4469 - val_custom_accuracy: 0.9381
# Epoch 43/50
# 79/79 [==============================] - 40s 506ms/step - loss: 0.3966 - custom_accuracy: 0.9519 - val_loss: 0.4461 - val_custom_accuracy: 0.9401
# Epoch 44/50
# 79/79 [==============================] - 39s 489ms/step - loss: 0.3965 - custom_accuracy: 0.9521 - val_loss: 0.4471 - val_custom_accuracy: 0.9381
# Epoch 45/50
# 79/79 [==============================] - 38s 479ms/step - loss: 0.3962 - custom_accuracy: 0.9500 - val_loss: 0.4480 - val_custom_accuracy: 0.9420
# Epoch 46/50
# 79/79 [==============================] - 38s 487ms/step - loss: 0.3961 - custom_accuracy: 0.9519 - val_loss: 0.4472 - val_custom_accuracy: 0.9401
# Epoch 47/50
# 79/79 [==============================] - 39s 497ms/step - loss: 0.3959 - custom_accuracy: 0.9504 - val_loss: 0.4469 - val_custom_accuracy: 0.9361
# Epoch 48/50
# 79/79 [==============================] - 38s 485ms/step - loss: 0.3959 - custom_accuracy: 0.9515 - val_loss: 0.4452 - val_custom_accuracy: 0.9420
# Epoch 49/50
# 79/79 [==============================] - 39s 493ms/step - loss: 0.3958 - custom_accuracy: 0.9515 - val_loss: 0.4475 - val_custom_accuracy: 0.9401
# Epoch 50/50
# 79/79 [==============================] - 39s 493ms/step - loss: 0.3958 - custom_accuracy: 0.9508 - val_loss: 0.4466 - val_custom_accuracy: 0.9381

# %%
plt.plot(history.history['loss'][1:], label='Training')
plt.plot(history.history['val_loss'][1:], label='Validation')
plt.title('Training a Quantum CNN ')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(history.history['val_custom_accuracy'], label='QCNN')
plt.title('Quantum vs Hybrid CNN performance')
plt.xlabel('Epochs')
plt.legend()
plt.ylabel('Validation Accuracy')
plt.show()
