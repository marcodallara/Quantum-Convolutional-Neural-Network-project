# %%
#libraries

import tensorflow as tf
import tensorflow_quantum as tfq
import cirq
import sympy
import numpy as np
#import seaborn as sns
import collections

# visualization tools
# %matplotlib inline
import matplotlib.pyplot as plt
from cirq.contrib.svg import SVGCircuit

# %% [markdown]
# ## Import the data

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Rescale the images from [0,255] to the [0.0,1.0] range.
x_train, x_test = x_train[..., np.newaxis]/255.0, x_test[..., np.newaxis]/255.0

print("Number of original training examples:", len(x_train))
print("Number of original test examples:", len(x_test))
# Out:
# Number of original training examples: 60000
# Number of original test examples: 10000

# %% [markdown]
# # Filter the 3 and 6 labels

# %%
def filter_36(x, y):
    keep = (y == 3) | (y == 6)
    x, y = x[keep], y[keep]
    y = y == 3
    return x,y

# %%
x_train, y_train = filter_36(x_train, y_train)
x_test, y_test = filter_36(x_test, y_test)

print("Number of filtered training examples:", len(x_train))
print("Number of filtered test examples:", len(x_test))
# Out:
# Number of filtered training examples: 12049
# Number of filtered test examples: 1968

# %%
print(y_train[0])

plt.imshow(x_train[0, :, :, 0])
plt.colorbar()
# Out:
# True

# %% [markdown]
# ## Rescale the image

# %%
x_train_small = tf.image.resize(x_train, (8,8)).numpy()
x_test_small = tf.image.resize(x_test, (8,8)).numpy()
x_train_small = x_train_small[0:5000]
x_test_small = x_test_small[0:500]
y_train = y_train[0:5000]
y_test = y_test[0:500]

# %%
print(y_train[0])

plt.imshow(x_train_small[0,:,:,0], vmin=0, vmax=1)
plt.colorbar()
# Out:
# True

# %% [markdown]
# ## Classical Convolutional Neural Network

# %% [markdown]
# ## CLASSICAL CNN with the same number of parameters of the QCNN

# %%
def create_classical_model():
    # A simple model based off LeNet from https://keras.io/examples/mnist_cnn/
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Conv2D(32, [3, 3], activation='relu', input_shape=(8,8,1)))
    model.add(tf.keras.layers.Conv2D(64, [3, 3], activation='relu'))
    model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(tf.keras.layers.Dropout(0.25))
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(128, activation='relu'))
    model.add(tf.keras.layers.Dropout(0.5))
    model.add(tf.keras.layers.Dense(1))
    return model


model = create_classical_model()
model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer=tf.keras.optimizers.Adam(),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 6, 6, 32)          320
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 64)          18496
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 64)         0
#  2D)
#
#  dropout_2 (Dropout)         (None, 2, 2, 64)          0
#
#  flatten_6 (Flatten)         (None, 256)               0
#
#  dense_12 (Dense)            (None, 128)               32896
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_13 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 51,841
# Trainable params: 51,841
# Non-trainable params: 0
# _________________________________________________________________

# %%
notfair_nn = model.fit(x_train_small,
          y_train,
          batch_size=128,
          epochs=50,
          verbose=1,
          validation_data=(x_test_small, y_test))

cnn_results = model.evaluate(x_test_small, y_test)
# Out:
# Epoch 1/50
# 40/40 [==============================] - 1s 9ms/step - loss: 0.3428 - accuracy: 0.8104 - val_loss: 0.0932 - val_accuracy: 0.9760
# Epoch 2/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0557 - accuracy: 0.9790 - val_loss: 0.0359 - val_accuracy: 0.9900
# Epoch 3/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0310 - accuracy: 0.9888 - val_loss: 0.0234 - val_accuracy: 0.9940
# Epoch 4/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0294 - accuracy: 0.9888 - val_loss: 0.0194 - val_accuracy: 0.9940
# Epoch 5/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0200 - accuracy: 0.9934 - val_loss: 0.0218 - val_accuracy: 0.9900
# Epoch 6/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0172 - accuracy: 0.9920 - val_loss: 0.0170 - val_accuracy: 0.9940
# Epoch 7/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0140 - accuracy: 0.9960 - val_loss: 0.0158 - val_accuracy: 0.9940
# Epoch 8/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0126 - accuracy: 0.9962 - val_loss: 0.0099 - val_accuracy: 0.9960
# Epoch 9/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0125 - accuracy: 0.9950 - val_loss: 0.0200 - val_accuracy: 0.9920
# Epoch 10/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0102 - accuracy: 0.9968 - val_loss: 0.0172 - val_accuracy: 0.9920
# Epoch 11/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0090 - accuracy: 0.9968 - val_loss: 0.0160 - val_accuracy: 0.9920
# Epoch 12/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0078 - accuracy: 0.9970 - val_loss: 0.0113 - val_accuracy: 0.9980
# Epoch 13/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0059 - accuracy: 0.9988 - val_loss: 0.0104 - val_accuracy: 0.9980
# Epoch 14/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.9984 - val_loss: 0.0117 - val_accuracy: 0.9980
# Epoch 15/50
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0055 - accuracy: 0.9984 - val_loss: 0.0082 - val_accuracy: 0.9980
# Epoch 16/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0095 - accuracy: 0.9968 - val_loss: 0.0153 - val_accuracy: 0.9960
# Epoch 17/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0043 - accuracy: 0.9990 - val_loss: 0.0073 - val_accuracy: 0.9980
# Epoch 18/50
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0062 - accuracy: 0.9982 - val_loss: 0.0132 - val_accuracy: 0.9980
# Epoch 19/50
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0038 - accuracy: 0.9990 - val_loss: 0.0078 - val_accuracy: 0.9980
# Epoch 20/50
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0031 - accuracy: 0.9988 - val_loss: 0.0103 - val_accuracy: 0.9980
# Epoch 21/50
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0039 - accuracy: 0.9986 - val_loss: 0.0095 - val_accuracy: 0.9980
# Epoch 22/50
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.0212 - val_accuracy: 0.9940
# Epoch 23/50
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.0080 - val_accuracy: 0.9980
# Epoch 24/50
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0026 - accuracy: 0.9992 - val_loss: 0.0096 - val_accuracy: 0.9980
# Epoch 25/50
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.0095 - val_accuracy: 0.9980
# Epoch 26/50
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0019 - accuracy: 0.9998 - val_loss: 0.0093 - val_accuracy: 0.9980
# Epoch 27/50
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0072 - val_accuracy: 0.9980
# Epoch 28/50
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0128 - val_accuracy: 0.9980
# Epoch 29/50
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0110 - val_accuracy: 0.9980
# Epoch 30/50
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0113 - val_accuracy: 0.9980
# Epoch 31/50
# 40/40 [==============================] - 0s 9ms/step - loss: 7.9488e-04 - accuracy: 1.0000 - val_loss: 0.0117 - val_accuracy: 0.9980
# Epoch 32/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0015 - accuracy: 0.9992 - val_loss: 0.0086 - val_accuracy: 0.9980
# Epoch 33/50
# 40/40 [==============================] - 0s 8ms/step - loss: 6.5534e-04 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 0.9980
# Epoch 34/50
# 40/40 [==============================] - 0s 9ms/step - loss: 5.9347e-04 - accuracy: 1.0000 - val_loss: 0.0174 - val_accuracy: 0.9960
# Epoch 35/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0144 - val_accuracy: 0.9980
# Epoch 36/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0017 - accuracy: 0.9992 - val_loss: 0.0088 - val_accuracy: 0.9980
# Epoch 37/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.0099 - val_accuracy: 0.9980
# Epoch 38/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0070 - val_accuracy: 0.9980
# Epoch 39/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0156 - val_accuracy: 0.9960
# Epoch 40/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0070 - val_accuracy: 0.9980
# Epoch 41/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.0098 - val_accuracy: 0.9980
# Epoch 42/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.9994 - val_loss: 0.0091 - val_accuracy: 0.9980
# Epoch 43/50
# 40/40 [==============================] - 0s 8ms/step - loss: 3.4321e-04 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9980
# Epoch 44/50
# 40/40 [==============================] - 0s 8ms/step - loss: 5.5448e-04 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 0.9980
# Epoch 45/50
# 40/40 [==============================] - 0s 8ms/step - loss: 9.9463e-04 - accuracy: 0.9994 - val_loss: 0.0111 - val_accuracy: 0.9980
# Epoch 46/50
# 40/40 [==============================] - 0s 9ms/step - loss: 8.4582e-04 - accuracy: 0.9996 - val_loss: 0.0064 - val_accuracy: 0.9980
# Epoch 47/50
# 40/40 [==============================] - 0s 9ms/step - loss: 6.7034e-04 - accuracy: 0.9998 - val_loss: 0.0103 - val_accuracy: 0.9980
# Epoch 48/50
# 40/40 [==============================] - 0s 8ms/step - loss: 3.8015e-04 - accuracy: 1.0000 - val_loss: 0.0121 - val_accuracy: 0.9980
# Epoch 49/50
# 40/40 [==============================] - 0s 8ms/step - loss: 1.6415e-04 - accuracy: 1.0000 - val_loss: 0.0092 - val_accuracy: 0.9980
# Epoch 50/50
# 40/40 [==============================] - 0s 11ms/step - loss: 3.9258e-04 - accuracy: 0.9998 - val_loss: 0.0230 - val_accuracy: 0.9960
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0230 - accuracy: 0.9960

# %%
def create_fair_classical_model():
    # A simple model based off LeNet from https://keras.io/examples/mnist_cnn/
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Flatten(input_shape=(8,8,1)))
    model.add(tf.keras.layers.Dense(3, activation='relu'))
    model.add(tf.keras.layers.Dense(1))
    return model


model = create_fair_classical_model()
model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer=tf.keras.optimizers.Adam(),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_7 (Flatten)         (None, 64)                0
#
#  dense_14 (Dense)            (None, 3)                 195
#
#  dense_15 (Dense)            (None, 1)                 4
#
# =================================================================
# Total params: 199
# Trainable params: 199
# Non-trainable params: 0
# _________________________________________________________________

# %%
fair_nn = model.fit(x_train_small,
          y_train,
          batch_size=128,
          epochs=50,
          verbose=2,
          validation_data=(x_test_small, y_test))

fair_nn_results = model.evaluate(x_test_small, y_test)
# Out:
# Epoch 1/50
# 40/40 - 1s - loss: 0.6527 - accuracy: 0.6738 - val_loss: 0.6237 - val_accuracy: 0.6200 - 635ms/epoch - 16ms/step
# Epoch 2/50
# 40/40 - 0s - loss: 0.5796 - accuracy: 0.7962 - val_loss: 0.5418 - val_accuracy: 0.8460 - 63ms/epoch - 2ms/step
# Epoch 3/50
# 40/40 - 0s - loss: 0.4864 - accuracy: 0.9012 - val_loss: 0.4624 - val_accuracy: 0.9020 - 69ms/epoch - 2ms/step
# Epoch 4/50
# 40/40 - 0s - loss: 0.4052 - accuracy: 0.9322 - val_loss: 0.3971 - val_accuracy: 0.9220 - 68ms/epoch - 2ms/step
# Epoch 5/50
# 40/40 - 0s - loss: 0.3401 - accuracy: 0.9464 - val_loss: 0.3435 - val_accuracy: 0.9400 - 70ms/epoch - 2ms/step
# Epoch 6/50
# 40/40 - 0s - loss: 0.2875 - accuracy: 0.9536 - val_loss: 0.2992 - val_accuracy: 0.9460 - 71ms/epoch - 2ms/step
# Epoch 7/50
# 40/40 - 0s - loss: 0.2460 - accuracy: 0.9578 - val_loss: 0.2635 - val_accuracy: 0.9540 - 72ms/epoch - 2ms/step
# Epoch 8/50
# 40/40 - 0s - loss: 0.2131 - accuracy: 0.9606 - val_loss: 0.2352 - val_accuracy: 0.9580 - 80ms/epoch - 2ms/step
# Epoch 9/50
# 40/40 - 0s - loss: 0.1869 - accuracy: 0.9650 - val_loss: 0.2120 - val_accuracy: 0.9580 - 80ms/epoch - 2ms/step
# Epoch 10/50
# 40/40 - 0s - loss: 0.1662 - accuracy: 0.9664 - val_loss: 0.1931 - val_accuracy: 0.9580 - 80ms/epoch - 2ms/step
# Epoch 11/50
# 40/40 - 0s - loss: 0.1497 - accuracy: 0.9686 - val_loss: 0.1776 - val_accuracy: 0.9620 - 82ms/epoch - 2ms/step
# Epoch 12/50
# 40/40 - 0s - loss: 0.1361 - accuracy: 0.9688 - val_loss: 0.1647 - val_accuracy: 0.9620 - 72ms/epoch - 2ms/step
# Epoch 13/50
# 40/40 - 0s - loss: 0.1252 - accuracy: 0.9710 - val_loss: 0.1542 - val_accuracy: 0.9620 - 68ms/epoch - 2ms/step
# Epoch 14/50
# 40/40 - 0s - loss: 0.1158 - accuracy: 0.9710 - val_loss: 0.1449 - val_accuracy: 0.9700 - 67ms/epoch - 2ms/step
# Epoch 15/50
# 40/40 - 0s - loss: 0.1079 - accuracy: 0.9726 - val_loss: 0.1369 - val_accuracy: 0.9700 - 64ms/epoch - 2ms/step
# Epoch 16/50
# 40/40 - 0s - loss: 0.1010 - accuracy: 0.9734 - val_loss: 0.1296 - val_accuracy: 0.9720 - 67ms/epoch - 2ms/step
# Epoch 17/50
# 40/40 - 0s - loss: 0.0951 - accuracy: 0.9742 - val_loss: 0.1238 - val_accuracy: 0.9720 - 67ms/epoch - 2ms/step
# Epoch 18/50
# 40/40 - 0s - loss: 0.0900 - accuracy: 0.9752 - val_loss: 0.1181 - val_accuracy: 0.9760 - 68ms/epoch - 2ms/step
# Epoch 19/50
# 40/40 - 0s - loss: 0.0855 - accuracy: 0.9762 - val_loss: 0.1132 - val_accuracy: 0.9780 - 77ms/epoch - 2ms/step
# Epoch 20/50
# 40/40 - 0s - loss: 0.0817 - accuracy: 0.9762 - val_loss: 0.1093 - val_accuracy: 0.9780 - 82ms/epoch - 2ms/step
# Epoch 21/50
# 40/40 - 0s - loss: 0.0781 - accuracy: 0.9780 - val_loss: 0.1062 - val_accuracy: 0.9780 - 84ms/epoch - 2ms/step
# Epoch 22/50
# 40/40 - 0s - loss: 0.0751 - accuracy: 0.9784 - val_loss: 0.1023 - val_accuracy: 0.9780 - 94ms/epoch - 2ms/step
# Epoch 23/50
# 40/40 - 0s - loss: 0.0723 - accuracy: 0.9800 - val_loss: 0.0998 - val_accuracy: 0.9780 - 74ms/epoch - 2ms/step
# Epoch 24/50
# 40/40 - 0s - loss: 0.0698 - accuracy: 0.9792 - val_loss: 0.0962 - val_accuracy: 0.9780 - 70ms/epoch - 2ms/step
# Epoch 25/50
# 40/40 - 0s - loss: 0.0676 - accuracy: 0.9786 - val_loss: 0.0935 - val_accuracy: 0.9780 - 71ms/epoch - 2ms/step
# Epoch 26/50
# 40/40 - 0s - loss: 0.0654 - accuracy: 0.9806 - val_loss: 0.0915 - val_accuracy: 0.9780 - 66ms/epoch - 2ms/step
# Epoch 27/50
# 40/40 - 0s - loss: 0.0635 - accuracy: 0.9808 - val_loss: 0.0893 - val_accuracy: 0.9780 - 102ms/epoch - 3ms/step
# Epoch 28/50
# 40/40 - 0s - loss: 0.0618 - accuracy: 0.9812 - val_loss: 0.0869 - val_accuracy: 0.9800 - 94ms/epoch - 2ms/step
# Epoch 29/50
# 40/40 - 0s - loss: 0.0602 - accuracy: 0.9812 - val_loss: 0.0847 - val_accuracy: 0.9800 - 105ms/epoch - 3ms/step
# Epoch 30/50
# 40/40 - 0s - loss: 0.0588 - accuracy: 0.9808 - val_loss: 0.0832 - val_accuracy: 0.9800 - 96ms/epoch - 2ms/step
# Epoch 31/50
# 40/40 - 0s - loss: 0.0573 - accuracy: 0.9824 - val_loss: 0.0829 - val_accuracy: 0.9820 - 94ms/epoch - 2ms/step
# Epoch 32/50
# 40/40 - 0s - loss: 0.0561 - accuracy: 0.9822 - val_loss: 0.0806 - val_accuracy: 0.9820 - 107ms/epoch - 3ms/step
# Epoch 33/50
# 40/40 - 0s - loss: 0.0550 - accuracy: 0.9832 - val_loss: 0.0799 - val_accuracy: 0.9860 - 83ms/epoch - 2ms/step
# Epoch 34/50
# 40/40 - 0s - loss: 0.0538 - accuracy: 0.9834 - val_loss: 0.0771 - val_accuracy: 0.9840 - 89ms/epoch - 2ms/step
# Epoch 35/50
# 40/40 - 0s - loss: 0.0528 - accuracy: 0.9828 - val_loss: 0.0759 - val_accuracy: 0.9840 - 91ms/epoch - 2ms/step
# Epoch 36/50
# 40/40 - 0s - loss: 0.0517 - accuracy: 0.9836 - val_loss: 0.0751 - val_accuracy: 0.9860 - 76ms/epoch - 2ms/step
# Epoch 37/50
# 40/40 - 0s - loss: 0.0509 - accuracy: 0.9838 - val_loss: 0.0735 - val_accuracy: 0.9860 - 77ms/epoch - 2ms/step
# Epoch 38/50
# 40/40 - 0s - loss: 0.0500 - accuracy: 0.9838 - val_loss: 0.0739 - val_accuracy: 0.9860 - 84ms/epoch - 2ms/step
# Epoch 39/50
# 40/40 - 0s - loss: 0.0493 - accuracy: 0.9836 - val_loss: 0.0714 - val_accuracy: 0.9860 - 102ms/epoch - 3ms/step
# Epoch 40/50
# 40/40 - 0s - loss: 0.0486 - accuracy: 0.9852 - val_loss: 0.0723 - val_accuracy: 0.9860 - 87ms/epoch - 2ms/step
# Epoch 41/50
# 40/40 - 0s - loss: 0.0479 - accuracy: 0.9844 - val_loss: 0.0711 - val_accuracy: 0.9860 - 76ms/epoch - 2ms/step
# Epoch 42/50
# 40/40 - 0s - loss: 0.0472 - accuracy: 0.9854 - val_loss: 0.0706 - val_accuracy: 0.9860 - 72ms/epoch - 2ms/step
# Epoch 43/50
# 40/40 - 0s - loss: 0.0465 - accuracy: 0.9854 - val_loss: 0.0689 - val_accuracy: 0.9860 - 67ms/epoch - 2ms/step
# Epoch 44/50
# 40/40 - 0s - loss: 0.0459 - accuracy: 0.9852 - val_loss: 0.0680 - val_accuracy: 0.9860 - 66ms/epoch - 2ms/step
# Epoch 45/50
# 40/40 - 0s - loss: 0.0453 - accuracy: 0.9854 - val_loss: 0.0670 - val_accuracy: 0.9860 - 66ms/epoch - 2ms/step
# Epoch 46/50
# 40/40 - 0s - loss: 0.0448 - accuracy: 0.9860 - val_loss: 0.0664 - val_accuracy: 0.9860 - 70ms/epoch - 2ms/step
# Epoch 47/50
# 40/40 - 0s - loss: 0.0443 - accuracy: 0.9862 - val_loss: 0.0657 - val_accuracy: 0.9860 - 77ms/epoch - 2ms/step
# Epoch 48/50
# 40/40 - 0s - loss: 0.0437 - accuracy: 0.9858 - val_loss: 0.0643 - val_accuracy: 0.9860 - 74ms/epoch - 2ms/step
# Epoch 49/50
# 40/40 - 0s - loss: 0.0433 - accuracy: 0.9862 - val_loss: 0.0644 - val_accuracy: 0.9860 - 72ms/epoch - 2ms/step
# Epoch 50/50
# 40/40 - 0s - loss: 0.0428 - accuracy: 0.9864 - val_loss: 0.0640 - val_accuracy: 0.9860 - 74ms/epoch - 2ms/step
# 16/16 [==============================] - 0s 1ms/step - loss: 0.0640 - accuracy: 0.9860

# %%
plt.plot(fair_nn.history['val_accuracy'], label='QCNN')
plt.title('Quantum vs Hybrid CNN performance')
plt.xlabel('Epochs')
plt.legend()
plt.ylabel('Validation Accuracy')
plt.show()


ll = np.loadtxt("5loss.txt")
vl = np.loadtxt("5val_loss.txt")


q = np.loadtxt("5val_acc.txt")
c = fair_nn.history['val_accuracy']
cc = notfair_nn.history['val_accuracy']

qnn_accuracy = np.mean(q[30:])
cnn_accuracy = np.mean(cc[30:])
fair_nn_accuracy = np.mean(c[30:])

# %%
fig, axLL = plt.subplots(1, 1 , figsize=(6, 6))


axLL.plot(c,"-.", marker= "o", markersize=2, label = "Fair Classical model", color="green")
axLL.plot(q,"-.", marker= "x", markersize=3, label = "Quantum model", color="violet")
axLL.plot(cc,"-.", marker= "x", markersize=3, label = "Not-fair Classical model", color="orange")

axLL.set_xlabel("epochs")
axLL.set_ylabel("Accuracy")
axLL.legend(loc = 'best')
axLL.set_title("Classical-Quantum comparison")
#axLL.set_ylim(-5.7,-5.1)
#plt.ylim(-0.2,0.1)
axLL.grid(True, which= "both")
l, b, h, w = .4, .4, .2, .45
ax3 = fig.add_axes([l, b, w, h])
plt.ylim(0.7, 1.1)
x = ["Quantum", "Not-fair \n Classical", "Fair Classical"]
y = [qnn_accuracy, cnn_accuracy, fair_nn_accuracy]
plt.bar(x,y, color=("violet","orange","green" ))
# Adding labels to each bar

for i in range(len(x)):
    plt.text(x[i], y[i], '{:.3f}'.format(y[i]), ha='center', va='bottom')
    
fig.savefig('5c.pdf')

# %%
fig, axLL = plt.subplots(1, 1 , figsize=(6, 6))


axLL.plot(ll,"-.", marker= "o", markersize=2, label = "Training Loss", color="green")
axLL.plot(vl,"-.", marker= "x", markersize=3, label = "Validation Loss", color="violet")

axLL.set_xlabel("epochs")
axLL.set_ylabel("Loss")
axLL.legend(loc = 'best')
axLL.set_title("Quantum model Loss function")
#axLL.set_ylim(-5.7,-5.1)
#plt.ylim(-0.2,0.1)
axLL.grid(True, which= "both")

fig.savefig('5l.pdf')
