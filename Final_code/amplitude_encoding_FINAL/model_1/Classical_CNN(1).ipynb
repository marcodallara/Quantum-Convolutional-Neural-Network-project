# %%
#libraries

import tensorflow as tf
import tensorflow_quantum as tfq
import cirq
import sympy
import numpy as np
#import seaborn as sns
import collections

# visualization tools
# %matplotlib inline
import matplotlib.pyplot as plt
from cirq.contrib.svg import SVGCircuit

# %% [markdown]
# ## Import the data

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Rescale the images from [0,255] to the [0.0,1.0] range.
x_train, x_test = x_train[..., np.newaxis]/255.0, x_test[..., np.newaxis]/255.0

print("Number of original training examples:", len(x_train))
print("Number of original test examples:", len(x_test))
# Out:
# Number of original training examples: 60000
# Number of original test examples: 10000

# %% [markdown]
# # Filter the 3 and 6 labels

# %%
def filter_36(x, y):
    keep = (y == 3) | (y == 6)
    x, y = x[keep], y[keep]
    y = y == 3
    return x,y

# %%
x_train, y_train = filter_36(x_train, y_train)
x_test, y_test = filter_36(x_test, y_test)

print("Number of filtered training examples:", len(x_train))
print("Number of filtered test examples:", len(x_test))
# Out:
# Number of filtered training examples: 12049
# Number of filtered test examples: 1968

# %%
print(y_train[0])

plt.imshow(x_train[0, :, :, 0])
plt.colorbar()
# Out:
# True

# %% [markdown]
# ## Rescale the image

# %%
x_train_small = tf.image.resize(x_train, (8,8)).numpy()
x_test_small = tf.image.resize(x_test, (8,8)).numpy()
x_train_small = x_train_small[0:5000]
x_test_small = x_test_small[0:500]
y_train = y_train[0:5000]
y_test = y_test[0:500]
# Out:
# 2023-07-07 16:47:26.913295: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 75571328 exceeds 10% of free system memory.

# %%
print(y_train[0])

plt.imshow(x_train_small[0,:,:,0], vmin=0, vmax=1)
plt.colorbar()
# Out:
# True

# %% [markdown]
# ## Classical Convolutional Neural Network

# %% [markdown]
# ## CLASSICAL CNN with the same number of parameters of the QCNN

# %%
def create_classical_model():
    # A simple model based off LeNet from https://keras.io/examples/mnist_cnn/
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Conv2D(32, [3, 3], activation='relu', input_shape=(8,8,1)))
    model.add(tf.keras.layers.Conv2D(64, [3, 3], activation='relu'))
    model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(tf.keras.layers.Dropout(0.25))
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(128, activation='relu'))
    model.add(tf.keras.layers.Dropout(0.5))
    model.add(tf.keras.layers.Dense(1))
    return model


model = create_classical_model()
model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer=tf.keras.optimizers.Adam(),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 6, 6, 32)          320
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 64)          18496
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 64)         0
#  2D)
#
#  dropout_2 (Dropout)         (None, 2, 2, 64)          0
#
#  flatten_2 (Flatten)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 51,841
# Trainable params: 51,841
# Non-trainable params: 0
# _________________________________________________________________

# %%
notfair_nn = model.fit(x_train_small,
          y_train,
          batch_size=128,
          epochs=50,
          verbose=1,
          validation_data=(x_test_small, y_test))

cnn_results = model.evaluate(x_test_small, y_test)
# Out:
# Epoch 1/50
# 40/40 [==============================] - 1s 8ms/step - loss: 0.3342 - accuracy: 0.8210 - val_loss: 0.0850 - val_accuracy: 0.9660
# Epoch 2/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0621 - accuracy: 0.9776 - val_loss: 0.0426 - val_accuracy: 0.9820
# Epoch 3/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0419 - accuracy: 0.9850 - val_loss: 0.0307 - val_accuracy: 0.9880
# Epoch 4/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0321 - accuracy: 0.9876 - val_loss: 0.0301 - val_accuracy: 0.9880
# Epoch 5/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0256 - accuracy: 0.9908 - val_loss: 0.0211 - val_accuracy: 0.9940
# Epoch 6/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0198 - accuracy: 0.9928 - val_loss: 0.0376 - val_accuracy: 0.9880
# Epoch 7/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0177 - accuracy: 0.9946 - val_loss: 0.0254 - val_accuracy: 0.9920
# Epoch 8/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0199 - accuracy: 0.9940 - val_loss: 0.0129 - val_accuracy: 0.9960
# Epoch 9/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0163 - accuracy: 0.9942 - val_loss: 0.0130 - val_accuracy: 0.9960
# Epoch 10/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0113 - accuracy: 0.9964 - val_loss: 0.0177 - val_accuracy: 0.9960
# Epoch 11/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0109 - accuracy: 0.9966 - val_loss: 0.0102 - val_accuracy: 0.9980
# Epoch 12/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0115 - accuracy: 0.9968 - val_loss: 0.0145 - val_accuracy: 0.9960
# Epoch 13/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0060 - accuracy: 0.9990 - val_loss: 0.0131 - val_accuracy: 0.9960
# Epoch 14/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0068 - accuracy: 0.9980 - val_loss: 0.0098 - val_accuracy: 0.9960
# Epoch 15/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0057 - accuracy: 0.9974 - val_loss: 0.0077 - val_accuracy: 0.9980
# Epoch 16/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0078 - accuracy: 0.9968 - val_loss: 0.0073 - val_accuracy: 0.9960
# Epoch 17/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0054 - accuracy: 0.9986 - val_loss: 0.0113 - val_accuracy: 0.9960
# Epoch 18/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 0.9976 - val_loss: 0.0207 - val_accuracy: 0.9920
# Epoch 19/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0067 - accuracy: 0.9978 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 20/50
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0048 - accuracy: 0.9988 - val_loss: 0.0110 - val_accuracy: 0.9960
# Epoch 21/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.0147 - val_accuracy: 0.9960
# Epoch 22/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0052 - accuracy: 0.9980 - val_loss: 0.0194 - val_accuracy: 0.9940
# Epoch 23/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0035 - accuracy: 0.9984 - val_loss: 0.0079 - val_accuracy: 0.9960
# Epoch 24/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0021 - accuracy: 0.9992 - val_loss: 0.0115 - val_accuracy: 0.9960
# Epoch 25/50
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0033 - accuracy: 0.9992 - val_loss: 0.0071 - val_accuracy: 0.9960
# Epoch 26/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0038 - accuracy: 0.9986 - val_loss: 0.0054 - val_accuracy: 0.9960
# Epoch 27/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0037 - accuracy: 0.9986 - val_loss: 0.0055 - val_accuracy: 0.9980
# Epoch 28/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0109 - val_accuracy: 0.9980
# Epoch 29/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0024 - accuracy: 0.9990 - val_loss: 0.0085 - val_accuracy: 0.9980
# Epoch 30/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0250 - val_accuracy: 0.9920
# Epoch 31/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0090 - val_accuracy: 0.9980
# Epoch 32/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.0055 - val_accuracy: 0.9980
# Epoch 33/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0048 - accuracy: 0.9984 - val_loss: 0.0109 - val_accuracy: 0.9960
# Epoch 34/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0031 - accuracy: 0.9994 - val_loss: 0.0193 - val_accuracy: 0.9940
# Epoch 35/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0134 - val_accuracy: 0.9960
# Epoch 36/50
# 40/40 [==============================] - 0s 8ms/step - loss: 6.9757e-04 - accuracy: 0.9998 - val_loss: 0.0086 - val_accuracy: 0.9980
# Epoch 37/50
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0114 - val_accuracy: 0.9980
# Epoch 38/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 0.0080 - val_accuracy: 0.9980
# Epoch 39/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 0.0183 - val_accuracy: 0.9920
# Epoch 40/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.9992 - val_loss: 0.0090 - val_accuracy: 0.9980
# Epoch 41/50
# 40/40 [==============================] - 0s 8ms/step - loss: 7.6660e-04 - accuracy: 0.9998 - val_loss: 0.0128 - val_accuracy: 0.9960
# Epoch 42/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0080 - val_accuracy: 0.9960
# Epoch 43/50
# 40/40 [==============================] - 0s 9ms/step - loss: 9.1634e-04 - accuracy: 0.9996 - val_loss: 0.0107 - val_accuracy: 0.9960
# Epoch 44/50
# 40/40 [==============================] - 0s 8ms/step - loss: 9.3830e-04 - accuracy: 0.9996 - val_loss: 0.0116 - val_accuracy: 0.9980
# Epoch 45/50
# 40/40 [==============================] - 0s 8ms/step - loss: 9.1476e-04 - accuracy: 0.9996 - val_loss: 0.0109 - val_accuracy: 0.9980
# Epoch 46/50
# 40/40 [==============================] - 0s 8ms/step - loss: 9.2363e-04 - accuracy: 0.9998 - val_loss: 0.0091 - val_accuracy: 0.9980
# Epoch 47/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0027 - accuracy: 0.9986 - val_loss: 0.0096 - val_accuracy: 0.9980
# Epoch 48/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0025 - accuracy: 0.9990 - val_loss: 0.0167 - val_accuracy: 0.9960
# Epoch 49/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.0142 - val_accuracy: 0.9960
# Epoch 50/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.0144 - val_accuracy: 0.9960
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0144 - accuracy: 0.9960

# %%
def create_fair_classical_model():
    # A simple model based off LeNet from https://keras.io/examples/mnist_cnn/
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Flatten(input_shape=(8,8,1)))
    model.add(tf.keras.layers.Dense(1, activation='relu'))
    model.add(tf.keras.layers.Dense(1))
    return model


model = create_fair_classical_model()
model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer=tf.keras.optimizers.Adam(),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_3 (Flatten)         (None, 64)                0
#
#  dense_6 (Dense)             (None, 1)                 65
#
#  dense_7 (Dense)             (None, 1)                 2
#
# =================================================================
# Total params: 67
# Trainable params: 67
# Non-trainable params: 0
# _________________________________________________________________

# %%
fair_nn = model.fit(x_train_small,
          y_train,
          batch_size=128,
          epochs=50,
          verbose=2,
          validation_data=(x_test_small, y_test))

fair_nn_results = model.evaluate(x_test_small, y_test)
# Out:
# Epoch 1/50
# 40/40 - 1s - loss: 0.7478 - accuracy: 0.4160 - val_loss: 0.7298 - val_accuracy: 0.4480 - 602ms/epoch - 15ms/step
# Epoch 2/50
# 40/40 - 0s - loss: 0.7040 - accuracy: 0.4848 - val_loss: 0.7011 - val_accuracy: 0.4620 - 58ms/epoch - 1ms/step
# Epoch 3/50
# 40/40 - 0s - loss: 0.6746 - accuracy: 0.4960 - val_loss: 0.6709 - val_accuracy: 0.4780 - 59ms/epoch - 1ms/step
# Epoch 4/50
# 40/40 - 0s - loss: 0.6328 - accuracy: 0.6230 - val_loss: 0.6291 - val_accuracy: 0.6420 - 57ms/epoch - 1ms/step
# Epoch 5/50
# 40/40 - 0s - loss: 0.5895 - accuracy: 0.7830 - val_loss: 0.5891 - val_accuracy: 0.7940 - 61ms/epoch - 2ms/step
# Epoch 6/50
# 40/40 - 0s - loss: 0.5502 - accuracy: 0.8706 - val_loss: 0.5522 - val_accuracy: 0.8640 - 67ms/epoch - 2ms/step
# Epoch 7/50
# 40/40 - 0s - loss: 0.5151 - accuracy: 0.9060 - val_loss: 0.5192 - val_accuracy: 0.9040 - 66ms/epoch - 2ms/step
# Epoch 8/50
# 40/40 - 0s - loss: 0.4837 - accuracy: 0.9214 - val_loss: 0.4889 - val_accuracy: 0.9220 - 74ms/epoch - 2ms/step
# Epoch 9/50
# 40/40 - 0s - loss: 0.4554 - accuracy: 0.9334 - val_loss: 0.4617 - val_accuracy: 0.9360 - 75ms/epoch - 2ms/step
# Epoch 10/50
# 40/40 - 0s - loss: 0.4300 - accuracy: 0.9424 - val_loss: 0.4372 - val_accuracy: 0.9480 - 68ms/epoch - 2ms/step
# Epoch 11/50
# 40/40 - 0s - loss: 0.4072 - accuracy: 0.9484 - val_loss: 0.4154 - val_accuracy: 0.9520 - 69ms/epoch - 2ms/step
# Epoch 12/50
# 40/40 - 0s - loss: 0.3866 - accuracy: 0.9514 - val_loss: 0.3957 - val_accuracy: 0.9580 - 61ms/epoch - 2ms/step
# Epoch 13/50
# 40/40 - 0s - loss: 0.3680 - accuracy: 0.9548 - val_loss: 0.3781 - val_accuracy: 0.9620 - 65ms/epoch - 2ms/step
# Epoch 14/50
# 40/40 - 0s - loss: 0.3511 - accuracy: 0.9574 - val_loss: 0.3623 - val_accuracy: 0.9660 - 61ms/epoch - 2ms/step
# Epoch 15/50
# 40/40 - 0s - loss: 0.3357 - accuracy: 0.9592 - val_loss: 0.3475 - val_accuracy: 0.9680 - 64ms/epoch - 2ms/step
# Epoch 16/50
# 40/40 - 0s - loss: 0.3216 - accuracy: 0.9604 - val_loss: 0.3346 - val_accuracy: 0.9680 - 66ms/epoch - 2ms/step
# Epoch 17/50
# 40/40 - 0s - loss: 0.3087 - accuracy: 0.9624 - val_loss: 0.3222 - val_accuracy: 0.9680 - 66ms/epoch - 2ms/step
# Epoch 18/50
# 40/40 - 0s - loss: 0.2968 - accuracy: 0.9638 - val_loss: 0.3103 - val_accuracy: 0.9680 - 71ms/epoch - 2ms/step
# Epoch 19/50
# 40/40 - 0s - loss: 0.2858 - accuracy: 0.9654 - val_loss: 0.2994 - val_accuracy: 0.9680 - 70ms/epoch - 2ms/step
# Epoch 20/50
# 40/40 - 0s - loss: 0.2754 - accuracy: 0.9674 - val_loss: 0.2900 - val_accuracy: 0.9680 - 71ms/epoch - 2ms/step
# Epoch 21/50
# 40/40 - 0s - loss: 0.2656 - accuracy: 0.9690 - val_loss: 0.2806 - val_accuracy: 0.9680 - 67ms/epoch - 2ms/step
# Epoch 22/50
# 40/40 - 0s - loss: 0.2565 - accuracy: 0.9694 - val_loss: 0.2719 - val_accuracy: 0.9700 - 67ms/epoch - 2ms/step
# Epoch 23/50
# 40/40 - 0s - loss: 0.2479 - accuracy: 0.9704 - val_loss: 0.2638 - val_accuracy: 0.9720 - 69ms/epoch - 2ms/step
# Epoch 24/50
# 40/40 - 0s - loss: 0.2398 - accuracy: 0.9716 - val_loss: 0.2563 - val_accuracy: 0.9700 - 66ms/epoch - 2ms/step
# Epoch 25/50
# 40/40 - 0s - loss: 0.2323 - accuracy: 0.9722 - val_loss: 0.2488 - val_accuracy: 0.9720 - 67ms/epoch - 2ms/step
# Epoch 26/50
# 40/40 - 0s - loss: 0.2250 - accuracy: 0.9730 - val_loss: 0.2421 - val_accuracy: 0.9720 - 68ms/epoch - 2ms/step
# Epoch 27/50
# 40/40 - 0s - loss: 0.2181 - accuracy: 0.9748 - val_loss: 0.2357 - val_accuracy: 0.9740 - 66ms/epoch - 2ms/step
# Epoch 28/50
# 40/40 - 0s - loss: 0.2117 - accuracy: 0.9752 - val_loss: 0.2289 - val_accuracy: 0.9760 - 70ms/epoch - 2ms/step
# Epoch 29/50
# 40/40 - 0s - loss: 0.2056 - accuracy: 0.9762 - val_loss: 0.2236 - val_accuracy: 0.9780 - 69ms/epoch - 2ms/step
# Epoch 30/50
# 40/40 - 0s - loss: 0.1997 - accuracy: 0.9762 - val_loss: 0.2177 - val_accuracy: 0.9800 - 66ms/epoch - 2ms/step
# Epoch 31/50
# 40/40 - 0s - loss: 0.1942 - accuracy: 0.9756 - val_loss: 0.2122 - val_accuracy: 0.9800 - 64ms/epoch - 2ms/step
# Epoch 32/50
# 40/40 - 0s - loss: 0.1890 - accuracy: 0.9766 - val_loss: 0.2074 - val_accuracy: 0.9800 - 64ms/epoch - 2ms/step
# Epoch 33/50
# 40/40 - 0s - loss: 0.1839 - accuracy: 0.9764 - val_loss: 0.2020 - val_accuracy: 0.9800 - 62ms/epoch - 2ms/step
# Epoch 34/50
# 40/40 - 0s - loss: 0.1791 - accuracy: 0.9772 - val_loss: 0.1976 - val_accuracy: 0.9800 - 64ms/epoch - 2ms/step
# Epoch 35/50
# 40/40 - 0s - loss: 0.1746 - accuracy: 0.9780 - val_loss: 0.1934 - val_accuracy: 0.9800 - 64ms/epoch - 2ms/step
# Epoch 36/50
# 40/40 - 0s - loss: 0.1701 - accuracy: 0.9786 - val_loss: 0.1884 - val_accuracy: 0.9800 - 64ms/epoch - 2ms/step
# Epoch 37/50
# 40/40 - 0s - loss: 0.1659 - accuracy: 0.9778 - val_loss: 0.1842 - val_accuracy: 0.9800 - 67ms/epoch - 2ms/step
# Epoch 38/50
# 40/40 - 0s - loss: 0.1618 - accuracy: 0.9790 - val_loss: 0.1800 - val_accuracy: 0.9820 - 65ms/epoch - 2ms/step
# Epoch 39/50
# 40/40 - 0s - loss: 0.1579 - accuracy: 0.9792 - val_loss: 0.1762 - val_accuracy: 0.9820 - 61ms/epoch - 2ms/step
# Epoch 40/50
# 40/40 - 0s - loss: 0.1541 - accuracy: 0.9796 - val_loss: 0.1727 - val_accuracy: 0.9820 - 60ms/epoch - 2ms/step
# Epoch 41/50
# 40/40 - 0s - loss: 0.1505 - accuracy: 0.9796 - val_loss: 0.1689 - val_accuracy: 0.9820 - 63ms/epoch - 2ms/step
# Epoch 42/50
# 40/40 - 0s - loss: 0.1470 - accuracy: 0.9800 - val_loss: 0.1658 - val_accuracy: 0.9820 - 65ms/epoch - 2ms/step
# Epoch 43/50
# 40/40 - 0s - loss: 0.1437 - accuracy: 0.9800 - val_loss: 0.1626 - val_accuracy: 0.9820 - 66ms/epoch - 2ms/step
# Epoch 44/50
# 40/40 - 0s - loss: 0.1405 - accuracy: 0.9802 - val_loss: 0.1587 - val_accuracy: 0.9820 - 63ms/epoch - 2ms/step
# Epoch 45/50
# 40/40 - 0s - loss: 0.1375 - accuracy: 0.9802 - val_loss: 0.1559 - val_accuracy: 0.9820 - 64ms/epoch - 2ms/step
# Epoch 46/50
# 40/40 - 0s - loss: 0.1345 - accuracy: 0.9804 - val_loss: 0.1533 - val_accuracy: 0.9820 - 61ms/epoch - 2ms/step
# Epoch 47/50
# 40/40 - 0s - loss: 0.1317 - accuracy: 0.9802 - val_loss: 0.1509 - val_accuracy: 0.9820 - 63ms/epoch - 2ms/step
# Epoch 48/50
# 40/40 - 0s - loss: 0.1290 - accuracy: 0.9804 - val_loss: 0.1475 - val_accuracy: 0.9800 - 66ms/epoch - 2ms/step
# Epoch 49/50
# 40/40 - 0s - loss: 0.1264 - accuracy: 0.9802 - val_loss: 0.1446 - val_accuracy: 0.9800 - 67ms/epoch - 2ms/step
# Epoch 50/50
# 40/40 - 0s - loss: 0.1238 - accuracy: 0.9802 - val_loss: 0.1420 - val_accuracy: 0.9800 - 60ms/epoch - 1ms/step
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1420 - accuracy: 0.9800

# %%
plt.plot(fair_nn.history['val_accuracy'], label='QCNN')
plt.title('Quantum vs Hybrid CNN performance')
plt.xlabel('Epochs')
plt.legend()
plt.ylabel('Validation Accuracy')
plt.show()


ll = np.loadtxt("1loss.txt")
vl = np.loadtxt("1val_loss.txt")


q = np.loadtxt("1val_acc.txt")
c = fair_nn.history['val_accuracy']
cc = notfair_nn.history['val_accuracy']

qnn_accuracy = np.mean(q[30:])
cnn_accuracy = np.mean(cc[30:])
fair_nn_accuracy = np.mean(c[30:])

# %%
fig, axLL = plt.subplots(1, 1 , figsize=(6, 6))


axLL.plot(c,"-.", marker= "o", markersize=2, label = "Fair Classical model", color="green")
axLL.plot(q,"-.", marker= "x", markersize=3, label = "Quantum model", color="violet")
axLL.plot(cc,"-.", marker= "x", markersize=3, label = "Not-fair Classical model", color="orange")

axLL.set_xlabel("epochs")
axLL.set_ylabel("Accuracy")
axLL.legend(loc = 'best')
axLL.set_title("Classical-Quantum comparison")
#axLL.set_ylim(-5.7,-5.1)
#plt.ylim(-0.2,0.1)
axLL.grid(True, which= "both")
l, b, h, w = .4, .4, .2, .45
ax3 = fig.add_axes([l, b, w, h])
plt.ylim(0.7, 1.1)
x = ["Quantum", "Not-fair \n Classical", "Fair Classical"]
y = [qnn_accuracy, cnn_accuracy, fair_nn_accuracy]
plt.bar(x,y, color=("violet","orange","green" ))
# Adding labels to each bar

for i in range(len(x)):
    plt.text(x[i], y[i], '{:.3f}'.format(y[i]), ha='center', va='bottom')
    
fig.savefig('1c.pdf')

# %%
fig, axLL = plt.subplots(1, 1 , figsize=(6, 6))


axLL.plot(ll,"-.", marker= "o", markersize=2, label = "Training Loss", color="green")
axLL.plot(vl,"-.", marker= "x", markersize=3, label = "Validation Loss", color="violet")

axLL.set_xlabel("epochs")
axLL.set_ylabel("Loss")
axLL.legend(loc = 'best')
axLL.set_title("Quantum model Loss function")
#axLL.set_ylim(-5.7,-5.1)
#plt.ylim(-0.2,0.1)
axLL.grid(True, which= "both")

fig.savefig('1l.pdf')
