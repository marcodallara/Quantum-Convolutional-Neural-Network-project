# %%
#libraries

import tensorflow as tf
import tensorflow_quantum as tfq
import cirq
import sympy
import numpy as np
#import seaborn as sns
import collections

# visualization tools
# %matplotlib inline
import matplotlib.pyplot as plt
from cirq.contrib.svg import SVGCircuit
# Out:
# 2023-07-07 16:51:19.894410: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-07-07 16:51:19.894430: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-07-07 16:51:23.254663: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-07-07 16:51:23.254703: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (marco-Lenovo-S340-15IWL): /proc/driver/nvidia/version does not exist
# 2023-07-07 16:51:23.255183: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Import the data

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Rescale the images from [0,255] to the [0.0,1.0] range.
x_train, x_test = x_train[..., np.newaxis]/255.0, x_test[..., np.newaxis]/255.0

print("Number of original training examples:", len(x_train))
print("Number of original test examples:", len(x_test))
# Out:
# Number of original training examples: 60000
# Number of original test examples: 10000

# %% [markdown]
# # Filter the 3 and 6 labels

# %%
def filter_36(x, y):
    keep = (y == 3) | (y == 6)
    x, y = x[keep], y[keep]
    y = y == 3
    return x,y

# %%
x_train, y_train = filter_36(x_train, y_train)
x_test, y_test = filter_36(x_test, y_test)

print("Number of filtered training examples:", len(x_train))
print("Number of filtered test examples:", len(x_test))
# Out:
# Number of filtered training examples: 12049
# Number of filtered test examples: 1968

# %%
print(y_train[0])

plt.imshow(x_train[0, :, :, 0])
plt.colorbar()
# Out:
# True

# %% [markdown]
# ## Rescale the image

# %%
x_train_small = tf.image.resize(x_train, (8,8)).numpy()
x_test_small = tf.image.resize(x_test, (8,8)).numpy()
x_train_small = x_train_small[0:5000]
x_test_small = x_test_small[0:500]
y_train = y_train[0:5000]
y_test = y_test[0:500]
# Out:
# 2023-07-07 16:51:26.000991: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 75571328 exceeds 10% of free system memory.

# %%
print(y_train[0])

plt.imshow(x_train_small[0,:,:,0], vmin=0, vmax=1)
plt.colorbar()
# Out:
# True

# %% [markdown]
# ## Classical Convolutional Neural Network

# %% [markdown]
# ## CLASSICAL CNN with the same number of parameters of the QCNN

# %%
def create_classical_model():
    # A simple model based off LeNet from https://keras.io/examples/mnist_cnn/
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Conv2D(32, [3,3], activation='relu', input_shape=(8,8,1)))
    model.add(tf.keras.layers.Conv2D(64, [3,3], activation='relu'))
    model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(tf.keras.layers.Dropout(0.25))
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(128, activation='relu'))
    model.add(tf.keras.layers.Dropout(0.5))
    model.add(tf.keras.layers.Dense(1))
    return model


model = create_classical_model()
model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer=tf.keras.optimizers.Adam(),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 6, 6, 32)          320
#
#  conv2d_1 (Conv2D)           (None, 4, 4, 64)          18496
#
#  max_pooling2d (MaxPooling2D  (None, 2, 2, 64)         0
#  )
#
#  dropout (Dropout)           (None, 2, 2, 64)          0
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 51,841
# Trainable params: 51,841
# Non-trainable params: 0
# _________________________________________________________________

# %%
notfair_nn = model.fit(x_train_small,
          y_train,
          batch_size=128,
          epochs=50,
          verbose=1,
          validation_data=(x_test_small, y_test))

cnn_results = model.evaluate(x_test_small, y_test)
# Out:
# Epoch 1/50
# 40/40 [==============================] - 1s 13ms/step - loss: 0.3554 - accuracy: 0.7948 - val_loss: 0.0931 - val_accuracy: 0.9640
# Epoch 2/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0610 - accuracy: 0.9772 - val_loss: 0.0436 - val_accuracy: 0.9860
# Epoch 3/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0354 - accuracy: 0.9874 - val_loss: 0.0335 - val_accuracy: 0.9920
# Epoch 4/50
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0251 - accuracy: 0.9926 - val_loss: 0.0228 - val_accuracy: 0.9920
# Epoch 5/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0214 - accuracy: 0.9926 - val_loss: 0.0185 - val_accuracy: 0.9920
# Epoch 6/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0154 - accuracy: 0.9936 - val_loss: 0.0273 - val_accuracy: 0.9940
# Epoch 7/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0166 - accuracy: 0.9934 - val_loss: 0.0185 - val_accuracy: 0.9920
# Epoch 8/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0146 - accuracy: 0.9954 - val_loss: 0.0173 - val_accuracy: 0.9940
# Epoch 9/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0106 - accuracy: 0.9966 - val_loss: 0.0142 - val_accuracy: 0.9940
# Epoch 10/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0090 - accuracy: 0.9974 - val_loss: 0.0201 - val_accuracy: 0.9940
# Epoch 11/50
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0111 - accuracy: 0.9956 - val_loss: 0.0213 - val_accuracy: 0.9940
# Epoch 12/50
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0081 - accuracy: 0.9976 - val_loss: 0.0151 - val_accuracy: 0.9940
# Epoch 13/50
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0065 - accuracy: 0.9978 - val_loss: 0.0212 - val_accuracy: 0.9940
# Epoch 14/50
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0071 - accuracy: 0.9980 - val_loss: 0.0231 - val_accuracy: 0.9920
# Epoch 15/50
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0080 - accuracy: 0.9972 - val_loss: 0.0126 - val_accuracy: 0.9960
# Epoch 16/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0051 - accuracy: 0.9988 - val_loss: 0.0101 - val_accuracy: 0.9960
# Epoch 17/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0055 - accuracy: 0.9980 - val_loss: 0.0140 - val_accuracy: 0.9940
# Epoch 18/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0040 - accuracy: 0.9992 - val_loss: 0.0180 - val_accuracy: 0.9940
# Epoch 19/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0047 - accuracy: 0.9988 - val_loss: 0.0223 - val_accuracy: 0.9940
# Epoch 20/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0037 - accuracy: 0.9992 - val_loss: 0.0125 - val_accuracy: 0.9960
# Epoch 21/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0129 - val_accuracy: 0.9960
# Epoch 22/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 0.0068 - val_accuracy: 0.9980
# Epoch 23/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0057 - accuracy: 0.9968 - val_loss: 0.0088 - val_accuracy: 0.9940
# Epoch 24/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0026 - accuracy: 0.9992 - val_loss: 0.0115 - val_accuracy: 0.9960
# Epoch 25/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.0120 - val_accuracy: 0.9960
# Epoch 26/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.0149 - val_accuracy: 0.9960
# Epoch 27/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0038 - accuracy: 0.9988 - val_loss: 0.0134 - val_accuracy: 0.9960
# Epoch 28/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.0162 - val_accuracy: 0.9940
# Epoch 29/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0026 - accuracy: 0.9988 - val_loss: 0.0206 - val_accuracy: 0.9920
# Epoch 30/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0083 - accuracy: 0.9974 - val_loss: 0.0166 - val_accuracy: 0.9940
# Epoch 31/50
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0038 - accuracy: 0.9988 - val_loss: 0.0242 - val_accuracy: 0.9940
# Epoch 32/50
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.0139 - val_accuracy: 0.9940
# Epoch 33/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0019 - accuracy: 0.9992 - val_loss: 0.0140 - val_accuracy: 0.9960
# Epoch 34/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0167 - val_accuracy: 0.9960
# Epoch 35/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0150 - val_accuracy: 0.9960
# Epoch 36/50
# 40/40 [==============================] - 0s 9ms/step - loss: 6.7352e-04 - accuracy: 1.0000 - val_loss: 0.0147 - val_accuracy: 0.9960
# Epoch 37/50
# 40/40 [==============================] - 0s 9ms/step - loss: 7.7384e-04 - accuracy: 0.9998 - val_loss: 0.0109 - val_accuracy: 0.9980
# Epoch 38/50
# 40/40 [==============================] - 0s 9ms/step - loss: 6.4873e-04 - accuracy: 0.9998 - val_loss: 0.0112 - val_accuracy: 0.9980
# Epoch 39/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0087 - val_accuracy: 0.9960
# Epoch 40/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 0.0089 - val_accuracy: 0.9940
# Epoch 41/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0126 - val_accuracy: 0.9960
# Epoch 42/50
# 40/40 [==============================] - 0s 9ms/step - loss: 6.7360e-04 - accuracy: 1.0000 - val_loss: 0.0158 - val_accuracy: 0.9960
# Epoch 43/50
# 40/40 [==============================] - 0s 8ms/step - loss: 5.4525e-04 - accuracy: 1.0000 - val_loss: 0.0131 - val_accuracy: 0.9960
# Epoch 44/50
# 40/40 [==============================] - 0s 9ms/step - loss: 2.3150e-04 - accuracy: 1.0000 - val_loss: 0.0119 - val_accuracy: 0.9960
# Epoch 45/50
# 40/40 [==============================] - 0s 8ms/step - loss: 3.3665e-04 - accuracy: 1.0000 - val_loss: 0.0157 - val_accuracy: 0.9960
# Epoch 46/50
# 40/40 [==============================] - 0s 8ms/step - loss: 4.0334e-04 - accuracy: 1.0000 - val_loss: 0.0246 - val_accuracy: 0.9940
# Epoch 47/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0064 - accuracy: 0.9976 - val_loss: 0.0216 - val_accuracy: 0.9960
# Epoch 48/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0268 - val_accuracy: 0.9940
# Epoch 49/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0017 - accuracy: 0.9998 - val_loss: 0.0221 - val_accuracy: 0.9960
# Epoch 50/50
# 40/40 [==============================] - 0s 9ms/step - loss: 5.8272e-04 - accuracy: 0.9998 - val_loss: 0.0187 - val_accuracy: 0.9960
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0187 - accuracy: 0.9960

# %%
def create_fair_classical_model():
    # A simple model based off LeNet from https://keras.io/examples/mnist_cnn/
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Flatten(input_shape=(8,8,1)))
    model.add(tf.keras.layers.Dense(1, activation='relu'))
    model.add(tf.keras.layers.Dense(1))
    return model


model = create_fair_classical_model()
model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer=tf.keras.optimizers.Adam(),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 1)                 65
#
#  dense_3 (Dense)             (None, 1)                 2
#
# =================================================================
# Total params: 67
# Trainable params: 67
# Non-trainable params: 0
# _________________________________________________________________

# %%
fair_nn = model.fit(x_train_small,
          y_train,
          batch_size=128,
          epochs=50,
          verbose=2,
          validation_data=(x_test_small, y_test))

fair_nn_results = model.evaluate(x_test_small, y_test)
# Out:
# Epoch 1/50
# 40/40 - 1s - loss: 0.6288 - accuracy: 0.7098 - val_loss: 0.5910 - val_accuracy: 0.7740 - 614ms/epoch - 15ms/step
# Epoch 2/50
# 40/40 - 0s - loss: 0.5716 - accuracy: 0.8172 - val_loss: 0.5429 - val_accuracy: 0.8400 - 66ms/epoch - 2ms/step
# Epoch 3/50
# 40/40 - 0s - loss: 0.5254 - accuracy: 0.8760 - val_loss: 0.5043 - val_accuracy: 0.8980 - 65ms/epoch - 2ms/step
# Epoch 4/50
# 40/40 - 0s - loss: 0.4871 - accuracy: 0.9048 - val_loss: 0.4731 - val_accuracy: 0.9160 - 66ms/epoch - 2ms/step
# Epoch 5/50
# 40/40 - 0s - loss: 0.4562 - accuracy: 0.9216 - val_loss: 0.4473 - val_accuracy: 0.9240 - 68ms/epoch - 2ms/step
# Epoch 6/50
# 40/40 - 0s - loss: 0.4300 - accuracy: 0.9350 - val_loss: 0.4253 - val_accuracy: 0.9320 - 68ms/epoch - 2ms/step
# Epoch 7/50
# 40/40 - 0s - loss: 0.4077 - accuracy: 0.9454 - val_loss: 0.4054 - val_accuracy: 0.9380 - 68ms/epoch - 2ms/step
# Epoch 8/50
# 40/40 - 0s - loss: 0.3881 - accuracy: 0.9504 - val_loss: 0.3878 - val_accuracy: 0.9500 - 75ms/epoch - 2ms/step
# Epoch 9/50
# 40/40 - 0s - loss: 0.3703 - accuracy: 0.9552 - val_loss: 0.3715 - val_accuracy: 0.9560 - 69ms/epoch - 2ms/step
# Epoch 10/50
# 40/40 - 0s - loss: 0.3542 - accuracy: 0.9602 - val_loss: 0.3562 - val_accuracy: 0.9620 - 69ms/epoch - 2ms/step
# Epoch 11/50
# 40/40 - 0s - loss: 0.3395 - accuracy: 0.9642 - val_loss: 0.3427 - val_accuracy: 0.9620 - 66ms/epoch - 2ms/step
# Epoch 12/50
# 40/40 - 0s - loss: 0.3261 - accuracy: 0.9664 - val_loss: 0.3301 - val_accuracy: 0.9640 - 67ms/epoch - 2ms/step
# Epoch 13/50
# 40/40 - 0s - loss: 0.3139 - accuracy: 0.9680 - val_loss: 0.3188 - val_accuracy: 0.9660 - 61ms/epoch - 2ms/step
# Epoch 14/50
# 40/40 - 0s - loss: 0.3023 - accuracy: 0.9694 - val_loss: 0.3076 - val_accuracy: 0.9700 - 62ms/epoch - 2ms/step
# Epoch 15/50
# 40/40 - 0s - loss: 0.2916 - accuracy: 0.9706 - val_loss: 0.2971 - val_accuracy: 0.9740 - 65ms/epoch - 2ms/step
# Epoch 16/50
# 40/40 - 0s - loss: 0.2814 - accuracy: 0.9716 - val_loss: 0.2877 - val_accuracy: 0.9760 - 68ms/epoch - 2ms/step
# Epoch 17/50
# 40/40 - 0s - loss: 0.2721 - accuracy: 0.9724 - val_loss: 0.2790 - val_accuracy: 0.9760 - 67ms/epoch - 2ms/step
# Epoch 18/50
# 40/40 - 0s - loss: 0.2632 - accuracy: 0.9730 - val_loss: 0.2705 - val_accuracy: 0.9780 - 66ms/epoch - 2ms/step
# Epoch 19/50
# 40/40 - 0s - loss: 0.2547 - accuracy: 0.9742 - val_loss: 0.2628 - val_accuracy: 0.9800 - 66ms/epoch - 2ms/step
# Epoch 20/50
# 40/40 - 0s - loss: 0.2469 - accuracy: 0.9754 - val_loss: 0.2556 - val_accuracy: 0.9780 - 63ms/epoch - 2ms/step
# Epoch 21/50
# 40/40 - 0s - loss: 0.2393 - accuracy: 0.9760 - val_loss: 0.2483 - val_accuracy: 0.9800 - 71ms/epoch - 2ms/step
# Epoch 22/50
# 40/40 - 0s - loss: 0.2323 - accuracy: 0.9764 - val_loss: 0.2412 - val_accuracy: 0.9800 - 69ms/epoch - 2ms/step
# Epoch 23/50
# 40/40 - 0s - loss: 0.2255 - accuracy: 0.9768 - val_loss: 0.2353 - val_accuracy: 0.9820 - 71ms/epoch - 2ms/step
# Epoch 24/50
# 40/40 - 0s - loss: 0.2190 - accuracy: 0.9780 - val_loss: 0.2293 - val_accuracy: 0.9820 - 68ms/epoch - 2ms/step
# Epoch 25/50
# 40/40 - 0s - loss: 0.2128 - accuracy: 0.9774 - val_loss: 0.2230 - val_accuracy: 0.9820 - 68ms/epoch - 2ms/step
# Epoch 26/50
# 40/40 - 0s - loss: 0.2069 - accuracy: 0.9778 - val_loss: 0.2165 - val_accuracy: 0.9820 - 68ms/epoch - 2ms/step
# Epoch 27/50
# 40/40 - 0s - loss: 0.2013 - accuracy: 0.9784 - val_loss: 0.2113 - val_accuracy: 0.9820 - 66ms/epoch - 2ms/step
# Epoch 28/50
# 40/40 - 0s - loss: 0.1958 - accuracy: 0.9790 - val_loss: 0.2067 - val_accuracy: 0.9820 - 72ms/epoch - 2ms/step
# Epoch 29/50
# 40/40 - 0s - loss: 0.1906 - accuracy: 0.9798 - val_loss: 0.2017 - val_accuracy: 0.9820 - 65ms/epoch - 2ms/step
# Epoch 30/50
# 40/40 - 0s - loss: 0.1857 - accuracy: 0.9798 - val_loss: 0.1969 - val_accuracy: 0.9840 - 69ms/epoch - 2ms/step
# Epoch 31/50
# 40/40 - 0s - loss: 0.1810 - accuracy: 0.9804 - val_loss: 0.1932 - val_accuracy: 0.9840 - 64ms/epoch - 2ms/step
# Epoch 32/50
# 40/40 - 0s - loss: 0.1764 - accuracy: 0.9810 - val_loss: 0.1887 - val_accuracy: 0.9840 - 65ms/epoch - 2ms/step
# Epoch 33/50
# 40/40 - 0s - loss: 0.1722 - accuracy: 0.9814 - val_loss: 0.1848 - val_accuracy: 0.9860 - 65ms/epoch - 2ms/step
# Epoch 34/50
# 40/40 - 0s - loss: 0.1681 - accuracy: 0.9824 - val_loss: 0.1808 - val_accuracy: 0.9860 - 66ms/epoch - 2ms/step
# Epoch 35/50
# 40/40 - 0s - loss: 0.1641 - accuracy: 0.9820 - val_loss: 0.1769 - val_accuracy: 0.9860 - 64ms/epoch - 2ms/step
# Epoch 36/50
# 40/40 - 0s - loss: 0.1602 - accuracy: 0.9824 - val_loss: 0.1726 - val_accuracy: 0.9860 - 64ms/epoch - 2ms/step
# Epoch 37/50
# 40/40 - 0s - loss: 0.1565 - accuracy: 0.9826 - val_loss: 0.1696 - val_accuracy: 0.9860 - 66ms/epoch - 2ms/step
# Epoch 38/50
# 40/40 - 0s - loss: 0.1529 - accuracy: 0.9828 - val_loss: 0.1665 - val_accuracy: 0.9860 - 64ms/epoch - 2ms/step
# Epoch 39/50
# 40/40 - 0s - loss: 0.1495 - accuracy: 0.9826 - val_loss: 0.1634 - val_accuracy: 0.9860 - 66ms/epoch - 2ms/step
# Epoch 40/50
# 40/40 - 0s - loss: 0.1463 - accuracy: 0.9830 - val_loss: 0.1600 - val_accuracy: 0.9860 - 63ms/epoch - 2ms/step
# Epoch 41/50
# 40/40 - 0s - loss: 0.1430 - accuracy: 0.9826 - val_loss: 0.1568 - val_accuracy: 0.9860 - 64ms/epoch - 2ms/step
# Epoch 42/50
# 40/40 - 0s - loss: 0.1400 - accuracy: 0.9834 - val_loss: 0.1548 - val_accuracy: 0.9880 - 62ms/epoch - 2ms/step
# Epoch 43/50
# 40/40 - 0s - loss: 0.1370 - accuracy: 0.9830 - val_loss: 0.1518 - val_accuracy: 0.9880 - 66ms/epoch - 2ms/step
# Epoch 44/50
# 40/40 - 0s - loss: 0.1342 - accuracy: 0.9836 - val_loss: 0.1492 - val_accuracy: 0.9880 - 67ms/epoch - 2ms/step
# Epoch 45/50
# 40/40 - 0s - loss: 0.1314 - accuracy: 0.9836 - val_loss: 0.1462 - val_accuracy: 0.9880 - 67ms/epoch - 2ms/step
# Epoch 46/50
# 40/40 - 0s - loss: 0.1287 - accuracy: 0.9834 - val_loss: 0.1434 - val_accuracy: 0.9880 - 64ms/epoch - 2ms/step
# Epoch 47/50
# 40/40 - 0s - loss: 0.1262 - accuracy: 0.9838 - val_loss: 0.1412 - val_accuracy: 0.9880 - 65ms/epoch - 2ms/step
# Epoch 48/50
# 40/40 - 0s - loss: 0.1236 - accuracy: 0.9838 - val_loss: 0.1393 - val_accuracy: 0.9880 - 68ms/epoch - 2ms/step
# Epoch 49/50
# 40/40 - 0s - loss: 0.1213 - accuracy: 0.9844 - val_loss: 0.1373 - val_accuracy: 0.9880 - 65ms/epoch - 2ms/step
# Epoch 50/50
# 40/40 - 0s - loss: 0.1188 - accuracy: 0.9842 - val_loss: 0.1340 - val_accuracy: 0.9880 - 71ms/epoch - 2ms/step
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1340 - accuracy: 0.9880

# %%
plt.plot(fair_nn.history['val_accuracy'], label='QCNN')
plt.title('Quantum vs Hybrid CNN performance')
plt.xlabel('Epochs')
plt.legend()
plt.ylabel('Validation Accuracy')
plt.show()


ll = np.loadtxt("3loss.txt")
vl = np.loadtxt("3val_loss.txt")


q = np.loadtxt("3val_acc.txt")[0:50]
c = fair_nn.history['val_accuracy']
cc = notfair_nn.history['val_accuracy']

qnn_accuracy = np.mean(q[30:])
cnn_accuracy = np.mean(cc[30:])
fair_nn_accuracy = np.mean(c[30:])

# %%
fig, axLL = plt.subplots(1, 1 , figsize=(6, 6))


axLL.plot(c,"-.", marker= "o", markersize=2, label = "Fair Classical model", color="green")
axLL.plot(q,"-.", marker= "x", markersize=3, label = "Quantum model", color="violet")
axLL.plot(cc,"-.", marker= "x", markersize=3, label = "Not-fair Classical model", color="orange")

axLL.set_xlabel("epochs")
axLL.set_ylabel("Accuracy")
axLL.legend(loc = 'best')
axLL.set_title("Classical-Quantum comparison")
#axLL.set_ylim(-5.7,-5.1)
#plt.ylim(-0.2,0.1)
axLL.grid(True, which= "both")
l, b, h, w = .4, .4, .2, .45
ax3 = fig.add_axes([l, b, w, h])
plt.ylim(0.7, 1.1)
x = ["Quantum", "Not-fair \n Classical", "Fair Classical"]
y = [qnn_accuracy, cnn_accuracy, fair_nn_accuracy]
plt.bar(x,y, color=("violet","orange","green" ))
# Adding labels to each bar

for i in range(len(x)):
    plt.text(x[i], y[i], '{:.3f}'.format(y[i]), ha='center', va='bottom')
    
fig.savefig('3c.pdf')

# %%
fig, axLL = plt.subplots(1, 1 , figsize=(6, 6))


axLL.plot(ll,"-.", marker= "o", markersize=2, label = "Training Loss", color="green")
axLL.plot(vl,"-.", marker= "x", markersize=3, label = "Validation Loss", color="violet")

axLL.set_xlabel("epochs")
axLL.set_ylabel("Loss")
axLL.legend(loc = 'best')
axLL.set_title("Quantum model Loss function")
#axLL.set_ylim(-5.7,-5.1)
#plt.ylim(-0.2,0.1)
axLL.grid(True, which= "both")

fig.savefig('3l.pdf')
